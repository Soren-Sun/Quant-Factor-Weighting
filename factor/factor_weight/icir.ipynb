# %% [markdown]
# ### **基于ICIR的因子加权方案**
#
# #### **1. 因子ICIR数据准备**
# | 因子            | IC均值   | IC标准差 | ICIR    | 方向稳定性（IC>0比例） |
# |-----------------|----------|----------|---------|---------------------|
# | pb             | -0.053   | 0.111    | -0.478  | 31.6%                |
# | MA20_deviation | -0.074   | 0.218    | -0.338  | 38.7%                |
# | ATR_ratio      | -0.031   | 0.216    | -0.142  | 36.8%                |
# | log_total_mv   | -0.062   | 0.266    | -0.234  | 34.9%                |
#
# #### **2. ICIR加权计算步骤**
# 1. **取ICIR绝对值**（保留方向信息）：
#    - |pb|            : **0.478**
#    - |MA20_deviation|: **0.338**
#    - |ATR_ratio|     : **0.142**
#    - |log_total_mv|  : **0.234**
#
# 2. **计算权重分配**：
#    - 总ICIR绝对值 = 0.478 + 0.338 + 0.142 + 0.234 = 1.192
#    - 权重 = 各因子ICIR绝对值 / 总ICIR绝对值
#
# 3. **最终权重结果**：
#    | 因子            | ICIR绝对值 | 权重计算       | 最终权重 |
#    |-----------------|------------|----------------|----------|
#    | pb             | 0.478      | 0.478/1.192    | 40.1%    |
#    | MA20_deviation | 0.338      | 0.338/1.192    | 28.4%    |
#    | log_total_mv   | 0.234      | 0.234/1.192    | 19.6%    |
#    | ATR_ratio      | 0.142      | 0.142/1.192    | 11.9%    |
